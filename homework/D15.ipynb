# %%
# !pip3 install pandas
# Out:
# Collecting pandas
#   Using cached https://files.pythonhosted.org/packages/11/1c/b0bc154996617eae877ff267fcf84e55e6c6808dbade0da206f0419dd483/pandas-1.2.1.tar.gz
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting numpy>=1.16.5 (from pandas)
#   Using cached https://files.pythonhosted.org/packages/51/60/3f0fe5b7675a461d96b9d6729beecd3532565743278a9c3fe6dd09697fa7/numpy-1.19.5.zip
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting python-dateutil>=2.7.3 (from pandas)
#   Using cached https://files.pythonhosted.org/packages/d4/70/d60450c3dd48ef87586924207ae8907090de0b306af2bce5d134d78615cb/python_dateutil-2.8.1-py2.py3-none-any.whl
# Collecting pytz>=2017.3 (from pandas)
#   Using cached https://files.pythonhosted.org/packages/89/06/2c2d3034b4d6bf22f2a4ae546d16925898658a33b4400cfb7e2c1e2871a3/pytz-2020.5-py2.py3-none-any.whl
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Building wheels for collected packages: pandas, numpy
#   Building wheel for pandas (PEP 517) ... done
#   Created wheel for pandas: filename=pandas-1.2.1-cp38-cp38-macosx_10_14_6_x86_64.whl size=15826213 sha256=b069ad487eb24f0251a6d872fba3086caf92e37ed22e4b5f931bda85a550bbeb
#   Stored in directory: /Users/jungseong/Library/Caches/pip/wheels/07/4a/7b/74705418d41de8ed7808beb6b53dd320557a3e95b09a6eccfd
#   Building wheel for numpy (PEP 517) ... done
#   Created wheel for numpy: filename=numpy-1.19.5-cp38-cp38-macosx_10_14_6_x86_64.whl size=6395059 sha256=9c2e85ad224c43591c2e4eebd53ff8e5ccaa4a5033c92a7b772a57c675ae0fa8
#   Stored in directory: /Users/jungseong/Library/Caches/pip/wheels/ee/cd/78/686734467766f26e3d2b42605dce9fdb7d24c1c1d26f2fb8fc
# Successfully built pandas numpy
# Installing collected packages: numpy, python-dateutil, pytz, pandas
# ERROR: Could not install packages due to an EnvironmentError: [Errno 13] Permission denied: '/Library/Python/3.8'
# Consider using the `--user` option or check the permissions.
#
# WARNING: You are using pip version 19.2.3, however version 21.0 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import pandas as pd
df = pd.DataFrame([[1,50,80,70,'boy',1],[2,60,45,50,'boy',2],[3,98,43,55,'boy',1],[4,70,69,89,'boy',2],[5,56,79,60,'girl',1],[6,60,68,55,'girl',2],[7,45,70,77,'girl',1],[8,55,77,76,'girl',2],[9,25,57,60,'girl',1],[10,88,40,43,'girl',3],[11,25,60,45,'boy',3],[12,80,60,23,'boy',3],[13,20,90,66,'girl',3],[14,50,50,50,'girl',3],[15,89,67,77,'girl',3]],columns=['student_id','math_score','english_score','chinese_score','sex','class'])
df.set_index('student_id',inplace=True)
df
# Out:
#             math_score  english_score  chinese_score   sex  class
# student_id
# 1                   50             80             70   boy      1
# 2                   60             45             50   boy      2
# 3                   98             43             55   boy      1
# 4                   70             69             89   boy      2
# 5                   56             79             60  girl      1
# 6                   60             68             55  girl      2
# 7                   45             70             77  girl      1
# 8                   55             77             76  girl      2
# 9                   25             57             60  girl      1
# 10                  88             40             43  girl      3
# 11                  25             60             45   boy      3
# 12                  80             60             23   boy      3
# 13                  20             90             66  girl      3
# 14                  50             50             50  girl      3
# 15                  89             67             77  girl      3

# %%
df.max()
# Out:
# math_score         98
# english_score      90
# chinese_score      89
# sex              girl
# class               3
# dtype: object

# %%
df.min()
# Out:
# math_score        20
# english_score     40
# chinese_score     23
# sex              boy
# class              1
# dtype: object

# %%
df.groupby('class').mean()
# Out:
#        math_score  english_score  chinese_score
# class
# 1       54.800000      65.800000      64.400000
# 2       61.250000      64.750000      67.500000
# 3       58.666667      61.166667      50.666667

# %%
df.groupby('sex').mean()
# Out:
#       math_score  english_score  chinese_score     class
# sex
# boy    63.833333      59.500000      55.333333  2.000000
# girl   54.222222      66.444444      62.666667  2.111111
